# %%
# running vit with cross entropy loss
# !python main.py
# Out:
# ...
# DIABETIC RETINOPATHY BINARY CLASSIFICATION
# ...
#
# Configuration:
#   Model:        vit_base_patch16_224
#   Batch Size:   32
#   Learning Rate: 0.0001
#   Epochs:       50
#   Image Size:   224
#   Loss:         ce
#   Optimizer:    adamw
#   Scheduler:    cosine
#
# Using device: cuda
#   GPU: NVIDIA GeForce RTX 4050 Laptop GPU
#   Memory: 6.18 GB
#
# Loading datasets...
# /home/arnav/remidio/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /home/arnav/remidio/src/dataset.py:107: UserWarning: Argument(s) 'value' are not valid for transform ShiftScaleRotate
#   A.ShiftScaleRotate(
# /home/arnav/remidio/src/dataset.py:131: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 50.0)),
# ...

# %%
# !python evaluate.py
# Out:
# Using device: cuda
#
# Loading test data...
# /home/arnav/remidio/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /home/arnav/remidio/src/dataset.py:107: UserWarning: Argument(s) 'value' are not valid for transform ShiftScaleRotate
#   A.ShiftScaleRotate(
# /home/arnav/remidio/src/dataset.py:131: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 50.0)),
# /home/arnav/remidio/src/dataset.py:140: UserWarning: Argument(s) 'max_holes, max_height, max_width, min_holes, fill_value' are not valid for transform CoarseDropout
#   A.CoarseDropout(
#
# ...
# DATASET INFORMATION
# ...
# Train samples: 2746
#   Distribution: {0: 1631, 1: 1115}
# Val samples:   366
#   Distribution: {0: 217, 1: 149}
# Test samples:  550
#   Distribution: {0: 327, 1: 223}
#
# Loading model...
# ...

# %%
# running vit with weighted cross entropy loss
# !python main.py
# Out:
# ...
# DIABETIC RETINOPATHY BINARY CLASSIFICATION
# ...
#
# Configuration:
#   Model:        vit_base_patch16_224
#   Batch Size:   32
#   Learning Rate: 0.0001
#   Epochs:       50
#   Image Size:   224
#   Loss:         weighted_ce
#   Optimizer:    adamw
#   Scheduler:    cosine
#
# Using device: cuda
#   GPU: NVIDIA GeForce RTX 4050 Laptop GPU
#   Memory: 6.18 GB
#
# Loading datasets...
# /home/arnav/remidio/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /home/arnav/remidio/src/dataset.py:107: UserWarning: Argument(s) 'value' are not valid for transform ShiftScaleRotate
#   A.ShiftScaleRotate(
# /home/arnav/remidio/src/dataset.py:131: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 50.0)),
# ...

# %%
# !python evaluate.py
# Out:
# Using device: cuda
#
# Loading test data...
# /home/arnav/remidio/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /home/arnav/remidio/src/dataset.py:107: UserWarning: Argument(s) 'value' are not valid for transform ShiftScaleRotate
#   A.ShiftScaleRotate(
# /home/arnav/remidio/src/dataset.py:131: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 50.0)),
# /home/arnav/remidio/src/dataset.py:140: UserWarning: Argument(s) 'max_holes, max_height, max_width, min_holes, fill_value' are not valid for transform CoarseDropout
#   A.CoarseDropout(
#
# ...
# DATASET INFORMATION
# ...
# Train samples: 2746
#   Distribution: {0: 1631, 1: 1115}
# Val samples:   366
#   Distribution: {0: 217, 1: 149}
# Test samples:  550
#   Distribution: {0: 327, 1: 223}
#
# Loading model...
# ...

# %%
#vit WCE with adam optimizer
# !python main.py
# Out:
# ...
# DIABETIC RETINOPATHY BINARY CLASSIFICATION
# ...
#
# Configuration:
#   Model:        vit_base_patch16_224
#   Batch Size:   32
#   Learning Rate: 0.0001
#   Epochs:       50
#   Image Size:   224
#   Loss:         weighted_ce
#   Optimizer:    adam
#   Scheduler:    cosine
#
# Using device: cuda
#   GPU: NVIDIA GeForce RTX 4050 Laptop GPU
#   Memory: 6.18 GB
#
# Loading datasets...
# /home/arnav/remidio/.venv/lib/python3.12/site-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)
# /home/arnav/remidio/src/dataset.py:107: UserWarning: Argument(s) 'value' are not valid for transform ShiftScaleRotate
#   A.ShiftScaleRotate(
# /home/arnav/remidio/src/dataset.py:131: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 50.0)),
# ...

# %%
# !python evaluate.py
# Out:
# Using device: cuda
#
# Loading test data...
# /home/arnav/remidio/src/dataset.py:107: UserWarning: Argument(s) 'mode, cval' are not valid for transform Affine
#   A.Affine(
# /home/arnav/remidio/src/dataset.py:131: UserWarning: Argument(s) 'var_limit' are not valid for transform GaussNoise
#   A.GaussNoise(var_limit=(10.0, 50.0), p=1.0),
# /home/arnav/remidio/src/dataset.py:137: UserWarning: Argument(s) 'fill_value' are not valid for transform CoarseDropout
#   A.CoarseDropout(
#
# ...
# DATASET INFORMATION
# ...
# Train samples: 2746
#   Distribution: {0: 1631, 1: 1115}
# Val samples:   366
#   Distribution: {0: 217, 1: 149}
# Test samples:  550
#   Distribution: {0: 327, 1: 223}
#
# Loading model...
# ✓ Model loaded from checkpoints/best_model.pth
#
# Running inference on test set...
#
# ...
# FINAL TEST SET EVALUATION RESULTS
# ...
#
# ...
# COMPREHENSIVE MODEL EVALUATION RESULTS
# ...
#
# ────────────────────────────────────────────────────────────────────────────────
# DATASET OVERVIEW
# ...

# %%
#vit WCE with sgd optimizer
# !python main.py
# Out:
# ...
# DIABETIC RETINOPATHY BINARY CLASSIFICATION
# ...
#
# Configuration:
#   Model:        vit_base_patch16_224
#   Batch Size:   32
#   Learning Rate: 0.0001
#   Epochs:       50
#   Image Size:   224
#   Loss:         weighted_ce
#   Optimizer:    sgd
#   Scheduler:    cosine
#
# Using device: cuda
#   GPU: NVIDIA GeForce RTX 4050 Laptop GPU
#   Memory: 6.18 GB
#
# Loading datasets...
#
# ...
# DATASET INFORMATION
# ...
# Train samples: 2746
#   Distribution: {0: 1631, 1: 1115}
# Val samples:   366
#   Distribution: {0: 217, 1: 149}
# Test samples:  550
#   Distribution: {0: 327, 1: 223}
#
# Creating model...
#   Total parameters: 85,898,882
#   Trainable parameters: 85,898,882
#
# ...
# TRAINING START
# ...
# Epoch 1 [Val]: 100%|███████████████| 12/12 [00:01<00:00, 10.64it/s, loss=0.4458]
#
# Epoch 1/50
# Train - Loss: 0.6026 | Acc: 0.6574 | F1: 0.4918 | AUC: 0.7302
# Val   - Loss: 0.4458 | Acc: 0.8443 | F1: 0.8131 | AUC: 0.8904
# ✓ New best F1: 0.8131 (saved to checkpoints/best_model.pth)
# ...

# %%
# !python evaluate.py
# Out:
# Using device: cuda
#
# Loading test data...
#
# ...
# DATASET INFORMATION
# ...
# Train samples: 2746
#   Distribution: {0: 1631, 1: 1115}
# Val samples:   366
#   Distribution: {0: 217, 1: 149}
# Test samples:  550
#   Distribution: {0: 327, 1: 223}
#
# Loading model...
# ✓ Model loaded from checkpoints/best_model.pth
#
# Running inference on test set...
#
# ...
# FINAL TEST SET EVALUATION RESULTS
# ...
#
# ...
# COMPREHENSIVE MODEL EVALUATION RESULTS
# ...
#
# ────────────────────────────────────────────────────────────────────────────────
# DATASET OVERVIEW
# ────────────────────────────────────────────────────────────────────────────────
# Total Test Samples:     550
#   ├─ Negative (No/Mild DR):     327 samples
#   └─ Positive (Moderate+ DR):   223 samples
# Class Balance: 59.5% Negative, 40.5% Positive
#
# ────────────────────────────────────────────────────────────────────────────────
# CORE PERFORMANCE METRICS
# ────────────────────────────────────────────────────────────────────────────────
# ...

# %%
#testing for determinism
#vit WCE with sgd optimizer
# !python main.py
# !python evaluate.py
# Out:
# ...
# DIABETIC RETINOPATHY BINARY CLASSIFICATION
# ...
#
# Configuration:
#   Model:        vit_base_patch16_224
#   Batch Size:   32
#   Learning Rate: 0.0001
#   Epochs:       50
#   Image Size:   224
#   Loss:         weighted_ce
#   Optimizer:    sgd
#   Scheduler:    cosine
#
# Using device: cuda
#   GPU: NVIDIA GeForce RTX 4050 Laptop GPU
#   Memory: 6.18 GB
#
# Loading datasets...
#
# ...
# DATASET INFORMATION
# ...
# Train samples: 2746
#   Distribution: {0: 1631, 1: 1115}
# Val samples:   366
#   Distribution: {0: 217, 1: 149}
# Test samples:  550
#   Distribution: {0: 327, 1: 223}
#
# Creating model...
#   Total parameters: 85,898,882
#   Trainable parameters: 85,898,882
#
# ...
# TRAINING START
# ...
# Epoch 1 [Val]: 100%|███████████████| 12/12 [00:01<00:00, 10.90it/s, loss=0.4423]
#
# Epoch 1/50
# Train - Loss: 0.5997 | Acc: 0.6732 | F1: 0.5269 | AUC: 0.7335
# Val   - Loss: 0.4423 | Acc: 0.8251 | F1: 0.7838 | AUC: 0.8905
# ✓ New best F1: 0.7838 (saved to checkpoints/best_model.pth)
# ...
